# %% [markdown]
# # 01. Importing Libraries

# %%
# import libraris
import pandas as pd
import numpy as np
import os

# %%
# import path
path = r'C:\Users\Bradley Allen\Desktop\Instacart Basket Analysis'

# %%
# importing data frame
df_ords_prods_merged = pd.read_pickle(r'C:\Users\Bradley Allen\Desktop\Instacart Basket Analysis\02 Data\Prepared Data\orders_prodcts_merged.pkl')

# %% [raw]
# # drop flag _merge column

# %%
df_ords_prods_merged_1 = df_ords_prods_merged.drop(columns = ['_merge'])

# %%
df_ords_prods_merged_1.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  first_order  product_id  add_to_cart_order  \
# 0                     NaN         True         196                  1
# 1                     NaN         True       14084                  2
# 2                     NaN         True       12427                  3
# 3                     NaN         True       26088                  4
# 4                     NaN         True       26405                  5
#
#    reordered                             product_name  aisle_id  \
# ...

# %%
df = df_ords_prods_merged_1[:1000000]

# %%
df.shape
# Out:
# (1000000, 14)

# %%
# Define a function
def price_label(row):
    if row['prices'] <= 5:
        return 'Low range product'
    elif (row['prices'] > 5) and (row['prices'] <= 15):
        return 'Mid range product'
    elif row['prices'] > 15:
        return 'High range product'
    else: return np.nan

# %%
# Apply the function
df['price_range'] = df.apply(price_label, axis=1)
# Out:
# C:\Users\BRADLE~1\AppData\Local\Temp/ipykernel_9428/902492192.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
df['price_range'].value_counts(dropna = False)
# Out:
# Mid range product     672525
# Low range product     314109
# High range product     12413
# NaN                      953
# Name: price_range, dtype: int64

# %%
df['prices'].max()
# Out:
# 99999.0

# %% [markdown]
# #### re-creating with the loc() function

# %%
df.loc[df['prices'] > 15, 'prices_range_loc'] = 'High range product'
# Out:
# C:\Users\Bradley Allen\Documents\anaconda_serena\lib\site-packages\pandas\core\indexing.py:1684: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# C:\Users\Bradley Allen\Documents\anaconda_serena\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid range product'

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low range product'

# %%
df['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid range product    672525
# Low range product    314109
# NaN                   13366
# Name: price_range_loc, dtype: int64

# %%
# filter with loc() on full dataframe
df_ords_prods_merged_1.loc[df_ords_prods_merged_1['prices'] > 15, 'price_range_loc'] = 'High range product'

# %%
df_ords_prods_merged_1.loc[(df_ords_prods_merged_1['prices'] <= 15) & (df_ords_prods_merged_1['prices'] > 5), 'price_range_loc'] = 'Mid range product'

# %%
df_ords_prods_merged_1.loc[df_ords_prods_merged_1['prices'] <= 5, 'price_range_loc'] = 'Low range prodct'

# %%
df_ords_prods_merged_1['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid range product     21860860
# Low range prodct      10126321
# High range product      417678
# NaN                      30200
# Name: price_range_loc, dtype: int64

# %% [markdown]
# ### creating a column that summarizes how busy each of the week is

# %%
# which days most orders take place
df_ords_prods_merged_1['orders_day_of_week'].value_counts(dropna = False)
# Out:
# 0    6209808
# 1    5665951
# 6    4500391
# 2    4217868
# 5    4209603
# 3    3844175
# 4    3787263
# Name: orders_day_of_week, dtype: int64

# %% [markdown]
# ##### note that 0 is Saturday

# %%
# loop
result = []
for value in df_ords_prods_merged_1["orders_day_of_week"]:
    if value == 0:
        result.append("Busiest day")
    elif value == 4:
        result.append("Least busy")
    else:
        result.append("regularly busy")

# %%
result
# Out:
# ['regularly busy',
#  'regularly busy',
#  'regularly busy',
#  'regularly busy',
#  'regularly busy',
#  'regularly busy',
#  'regularly busy',
#  'regularly busy',
#  'regularly busy',
#  'regularly busy',
#  'regularly busy',
#  'regularly busy',
#  'regularly busy',
#  'regularly busy',
#  'regularly busy',
#  'regularly busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'regularly busy',
#  'regularly busy',
#  'regularly busy',
#  'regularly busy',
#  'regularly busy',
#  'regularly busy',
#  'regularly busy',
#  'regularly busy',
#  'regularly busy',
#  'regularly busy',
#  'regularly busy',
#  'regularly busy',
#  'regularly busy',
#  'regularly busy',
#  'regularly busy',
#  'regularly busy',
#  'regularly busy',
#  'regularly busy',
#  'regularly busy',
#  'regularly busy',
#  'regularly busy',
# ...

# %%
df_ords_prods_merged_1['busiest_day'] = result

# %%
df_ords_prods_merged_1['busiest_day'].value_counts(dropna = False)
# Out:
# regularly busy    22437988
# Busiest day        6209808
# Least busy         3787263
# Name: busiest_day, dtype: int64

# %% [markdown]
# # 4.7 Task Answers

# %%
# 02. busiest days and slowest days
new_result = []
for value in df_ords_prods_merged_1["orders_day_of_week"]:
    if value == 0:
        new_result.append("Busiest_days")
    elif value == 1:
        new_result.append("Busiest_days")
    elif value == 3:
        new_result.append("Slowest_days")
    elif value == 4:
        new_result.append("Slowest_days")
    else:
        new_result.append("Regularly busy")

# %%
new_result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Slowest_days',
# ...

# %%
df_ords_prods_merged_1['Busiest_days'] = new_result

# %%
df_ords_prods_merged_1['Busiest_days'].value_counts(dropna = False)
# Out:
# Regularly busy    12927862
# Busiest_days      11875759
# Slowest_days       7631438
# Name: Busiest_days, dtype: int64

# %%
# 04. labeling periods of time during the day

# %%
df_ords_prods_merged_1['order_hour_of_day'].value_counts(dropna = False)
# Out:
# 10    2764476
# 11    2738647
# 14    2691598
# 15    2664583
# 13    2663346
# 12    2620898
# 16    2537506
# 9     2456751
# 17    2089510
# 8     1719991
# 18    1637956
# 19    1259416
# 20     977049
# 7      891951
# 21     796379
# 22     634743
# 23     402621
# 6      290796
# 0      218951
# 1      115787
# 5       88064
# 2       69435
# 4       53284
# 3       51321
# Name: order_hour_of_day, dtype: int64

# %%
## 10 am has the highest  volume of orders, and the volume of orders is a listed in the output in descending order

# %%
updated_result = []
for value in df_ords_prods_merged_1["order_hour_of_day"]:
    if value > 10 & value <= 18:
        updated_result.append("Most_orders")
    elif value  <= 5:
        updated_result.append("Fewest_orders")
    else:
        updated_result.append("Average_orders")

# %%
updated_result
# Out:
# ['Average_orders',
#  'Average_orders',
#  'Average_orders',
#  'Average_orders',
#  'Average_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Average_orders',
#  'Average_orders',
#  'Average_orders',
#  'Average_orders',
# ...

# %%
# creating new column for busiest_period_of_day

# %%
df_ords_prods_merged_1['busiest_period_of_day'] = updated_result

# %%
# 05. busiest_period_of_day column frequency
df_ords_prods_merged_1['busiest_period_of_day'].value_counts(dropna = False)
# Out:
# Most_orders       27662206
# Average_orders     4484467
# Fewest_orders       288386
# Name: busiest_period_of_day, dtype: int64

# %%
df_ords_prods_merged_1.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  first_order  product_id  add_to_cart_order  \
# 0                     NaN         True         196                  1
# 1                     NaN         True       14084                  2
# 2                     NaN         True       12427                  3
# 3                     NaN         True       26088                  4
# 4                     NaN         True       26405                  5
#
#    reordered                             product_name  aisle_id  \
# ...

# %%
# 07. exporting dataframe as a pickle file

# %%
df_ords_prods_merged_1.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged_new.pkl'))
