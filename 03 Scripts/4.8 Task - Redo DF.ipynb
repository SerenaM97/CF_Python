# %%
import pandas as pd
import numpy as np
import os

# %%
# import path
path = r'C:\Users\Bradley Allen\Desktop\Instacart Basket Analysis'

# %%
# importing DF from 4.7 task
df = pd.read_pickle(r'C:\Users\Bradley Allen\Desktop\Instacart Basket Analysis\02 Data\Prepared Data\orders_prodcts_merged.pkl')

# %%
df.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  first_order  product_id  add_to_cart_order  \
# 0                     NaN         True         196                  1
# 1                     NaN         True       14084                  2
# 2                     NaN         True       12427                  3
# 3                     NaN         True       26088                  4
# 4                     NaN         True       26405                  5
#
#    reordered                             product_name  aisle_id  \
# ...

# %%
df.shape
# Out:
# (32435059, 15)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import scipy

# %% [markdown]
# # splitting dataframe due to reduced memory ability #

# %%
np.random.seed(4)

# %%
dev = np.random.rand(len(df)) < 0.8

# %%
dev
# Out:
# array([False,  True, False, ...,  True,  True,  True])

# %%
# 80% of dataframe goimg into big_df
big_df = df[dev]

# %%
# 20% of data going into df_reduced
df_reduced = df[~dev]

# %%
# checking the size of of df_reduced. Checks out to 20% of original df.
len(df_reduced)
# Out:
# 6487327

# %%
df_reduced.head()
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 2    2539329        1             1                   2                  8
# 6    2398795        1             2                   3                  7
# 12    473747        1             3                   3                 12
# 13    473747        1             3                   3                 12
#
#     days_since_prior_order  first_order  product_id  add_to_cart_order  \
# 0                      NaN         True         196                  1
# 2                      NaN         True       12427                  3
# 6                     15.0        False       10258                  2
# 12                    21.0        False       12427                  2
# 13                    21.0        False       10258                  3
#
#     reordered         product_name  aisle_id  department_id  prices _merge
# ...

# %%
df_reduced.shape
# Out:
# (6487327, 15)

# %%
# 02. find the aggregate mean of "order_number" column grouped by "department_id" for entire dataframe

# %%
df_reduced.groupby('product_name')

# %%
df_reduced.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1.0              15.426080
# 2.0              17.199197
# 3.0              17.229216
# 4.0              17.802510
# 5.0              15.301468
# 6.0              16.468600
# 7.0              17.193223
# 8.0              15.378712
# 9.0              15.913116
# 10.0             20.154380
# 11.0             16.067933
# 12.0             15.901642
# 13.0             16.544453
# 14.0             16.737975
# 15.0             16.150551
# 16.0             17.663927
# 17.0             15.752120
# 18.0             19.239151
# 19.0             17.186123
# 20.0             16.477720
# 21.0             22.839194

# %%
df_reduced.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1.0              15.426080   1  99
# 2.0              17.199197   1  99
# 3.0              17.229216   1  99
# 4.0              17.802510   1  99
# 5.0              15.301468   1  99
# 6.0              16.468600   1  99
# 7.0              17.193223   1  99
# 8.0              15.378712   1  99
# 9.0              15.913116   1  99
# 10.0             20.154380   1  99
# 11.0             16.067933   1  99
# 12.0             15.901642   1  99
# 13.0             16.544453   1  99
# 14.0             16.737975   1  99
# 15.0             16.150551   1  99
# 16.0             17.663927   1  99
# 17.0             15.752120   1  99
# 18.0             19.239151   1  99
# 19.0             17.186123   1  99
# 20.0             16.477720   1  99
# 21.0             22.839194   1  99

# %%
df_reduced['max_order'] = df_reduced.groupby(['user_id'])['order_number'].transform(np.max)
# Out:
# C:\Users\BRADLE~1\AppData\Local\Temp/ipykernel_2012/862127639.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_reduced['max_order'] = df_reduced.groupby(['user_id'])['order_number'].transform(np.max)

# %%
df_reduced.head()
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 2    2539329        1             1                   2                  8
# 6    2398795        1             2                   3                  7
# 12    473747        1             3                   3                 12
# 13    473747        1             3                   3                 12
#
#     days_since_prior_order  first_order  product_id  add_to_cart_order  \
# 0                      NaN         True         196                  1
# 2                      NaN         True       12427                  3
# 6                     15.0        False       10258                  2
# 12                    21.0        False       12427                  2
# 13                    21.0        False       10258                  3
#
#     reordered         product_name  aisle_id  department_id  prices _merge  \
# ...

# %%
pd.options.display.max_rows = None

# %%
df_reduced.sort_values(by = 'user_id', ascending=True).head(100)
# Out:
#      order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0     2539329        1             1                   2                  8
# 58    2550362        1            10                   4                  8
# 50    2550362        1            10                   4                  8
# 31    3367565        1             6                   2                  7
# 23     431534        1             5                   4                 15
# 21     431534        1             5                   4                 15
# 56    2550362        1            10                   4                  8
# 13     473747        1             3                   3                 12
# 12     473747        1             3                   3                 12
# 6     2398795        1             2                   3                  7
# 2     2539329        1             1                   2                  8
# ...

# %%
## loyalty flags
df_reduced.loc[df_reduced['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'
# Out:
# C:\Users\Bradley Allen\Documents\anaconda_serena\lib\site-packages\pandas\core\indexing.py:1684: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# C:\Users\Bradley Allen\Documents\anaconda_serena\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
df_reduced.loc[(df_reduced['max_order'] <= 40) & (df_reduced['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
df_reduced.loc[df_reduced['max_order'] <=10, 'loyalty_flag'] = 'New customer'

# %%
df_reduced['loyalty_flag'].value_counts()
# Out:
# Regular customer    3165470
# Loyal customer      2043798
# New customer        1278059
# Name: loyalty_flag, dtype: int64

# %%
df_reduced[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#      user_id      loyalty_flag  order_number
# 0          1      New customer             1
# 2          1      New customer             1
# 6          1      New customer             2
# 12         1      New customer             3
# 13         1      New customer             3
# 19         1      New customer             4
# 21         1      New customer             5
# 23         1      New customer             5
# 31         1      New customer             6
# 50         1      New customer            10
# 56         1      New customer            10
# 58         1      New customer            10
# 60         2  Regular customer             1
# 64         2  Regular customer             1
# 65         2  Regular customer             1
# 71         2  Regular customer             1
# 85         2  Regular customer             4
# 87         2  Regular customer             4
# 89         2  Regular customer             4
# 93         2  Regular customer             4
# ...

# %%
df_reduced.agg({'order_number': ['mean', 'min', 'max']})
# Out:
#       order_number
# mean     17.133992
# min       1.000000
# max      99.000000

# %% [markdown]
# minimum and maximum values have remained the same, as they are expected to. Mean value has changed to 17.15

# %%
## re-run loyalty flag application

# %%
df_reduced.loc[df_reduced['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'
# Out:
# C:\Users\Bradley Allen\Documents\anaconda_serena\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
df_reduced.loc[(df_reduced['max_order'] <= 40) & (df_reduced['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'
# Out:
# C:\Users\Bradley Allen\Documents\anaconda_serena\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
df_reduced.loc[df_reduced['max_order'] <=10, 'loyalty_flag'] = 'New customer'

# %%
df_reduced[['user_id', 'loyalty_flag', 'order_number']].head(10)
# Out:
#     user_id  loyalty_flag  order_number
# 0         1  New customer             1
# 2         1  New customer             1
# 6         1  New customer             2
# 12        1  New customer             3
# 13        1  New customer             3
# 19        1  New customer             4
# 21        1  New customer             5
# 23        1  New customer             5
# 31        1  New customer             6
# 50        1  New customer            10

# %%
df_reduced.groupby('loyalty_flag').agg({'prices': ['mean', 'min', 'max']})
# Out:
#                      prices
#                        mean  min      max
# loyalty_flag
# Loyal customer    10.439154  1.0  99999.0
# New customer      13.245550  1.0  99999.0
# Regular customer  12.226696  1.0  99999.0

# %%
# max values of 9999 look suspicious

# %%
# clean max prices
df_clean = df_reduced[df_reduced.prices <200.0]

# %%
df_clean.shape
# Out:
# (6480166, 18)

# %%
df_clean.groupby('loyalty_flag').agg({'prices': ['mean', 'min', 'max']})
# Out:
#                     prices
#                       mean  min   max
# loyalty_flag
# Loyal customer    7.781117  1.0  25.0
# New customer      7.793945  1.0  25.0
# Regular customer  7.798853  1.0  25.0

# %%
## loyal customers pay the lowest verage price by about 1-2 cents

# %%
## flag spending habit

# %% [markdown]
# note that df_clean is being used, in order to exclude the maximum price of 9999. df_clean has a max price limit of 200.0

# %%
df_clean['user_avg_price'] = df_clean.groupby(['user_id'])['prices'].transform(np.max)
# Out:
# C:\Users\BRADLE~1\AppData\Local\Temp/ipykernel_2012/457181213.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['user_avg_price'] = df_clean.groupby(['user_id'])['prices'].transform(np.max)

# %%
df_clean.head()
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 2    2539329        1             1                   2                  8
# 6    2398795        1             2                   3                  7
# 12    473747        1             3                   3                 12
# 13    473747        1             3                   3                 12
#
#     days_since_prior_order  first_order  product_id  add_to_cart_order  \
# 0                      NaN         True         196                  1
# 2                      NaN         True       12427                  3
# 6                     15.0        False       10258                  2
# 12                    21.0        False       12427                  2
# 13                    21.0        False       10258                  3
#
#     reordered         product_name  aisle_id  department_id  prices _merge  \
# ...

# %%
df_clean['user_avg_price'] = df_clean.groupby(['user_id'])['prices'].transform(np.mean)
# Out:
# C:\Users\BRADLE~1\AppData\Local\Temp/ipykernel_2012/2617355750.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['user_avg_price'] = df_clean.groupby(['user_id'])['prices'].transform(np.mean)

# %%
df_clean.head()
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 2    2539329        1             1                   2                  8
# 6    2398795        1             2                   3                  7
# 12    473747        1             3                   3                 12
# 13    473747        1             3                   3                 12
#
#     days_since_prior_order  first_order  product_id  add_to_cart_order  \
# 0                      NaN         True         196                  1
# 2                      NaN         True       12427                  3
# 6                     15.0        False       10258                  2
# 12                    21.0        False       12427                  2
# 13                    21.0        False       10258                  3
#
#     reordered         product_name  aisle_id  department_id  prices _merge  \
# ...

# %%
# dropping typo "loyality_flag" because of typo
df_clean = df_clean.drop('loyality_flag', 1)
# Out:
# C:\Users\BRADLE~1\AppData\Local\Temp/ipykernel_2012/1720706451.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df_clean = df_clean.drop('loyality_flag', 1)

# %%
df_clean.head()
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 2    2539329        1             1                   2                  8
# 6    2398795        1             2                   3                  7
# 12    473747        1             3                   3                 12
# 13    473747        1             3                   3                 12
#
#     days_since_prior_order  first_order  product_id  add_to_cart_order  \
# 0                      NaN         True         196                  1
# 2                      NaN         True       12427                  3
# 6                     15.0        False       10258                  2
# 12                    21.0        False       12427                  2
# 13                    21.0        False       10258                  3
#
#     reordered         product_name  aisle_id  department_id  prices _merge  \
# ...

# %%
df_clean.sort_values(by='user_id', ascending = True).head()
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 58   2550362        1            10                   4                  8
# 50   2550362        1            10                   4                  8
# 31   3367565        1             6                   2                  7
# 23    431534        1             5                   4                 15
#
#     days_since_prior_order  first_order  product_id  add_to_cart_order  \
# 0                      NaN         True         196                  1
# 58                    30.0        False       12427                  9
# 50                    30.0        False         196                  1
# 31                    19.0        False       10258                  3
# 23                    28.0        False       10258                  3
#
#     reordered         product_name  aisle_id  department_id  prices _merge  \
# ...

# %%
df_clean.shape
# Out:
# (6480166, 18)

# %%
# 06. different spenders
df_clean['user_avg_price'].describe()
# Out:
# count    6.480166e+06
# mean     7.792298e+00
# std      9.880442e-01
# min      1.000000e+00
# 25%      7.242636e+00
# 50%      7.800000e+00
# 75%      8.352000e+00
# max      2.500000e+01
# Name: user_avg_price, dtype: float64

# %%
df_clean.loc[df_clean['user_avg_price'] < 10, 'spending_habit'] = 'Lower spender'

# %%
df_clean.loc[df_clean['user_avg_price'] >= 10, 'spending_habit'] = 'Higher spender'

# %%
df_clean[['user_id', 'user_avg_price', 'spending_habit']].head()
# Out:
#     user_id  user_avg_price spending_habit
# 0         1           5.175  Lower spender
# 2         1           5.175  Lower spender
# 6         1           5.175  Lower spender
# 12        1           5.175  Lower spender
# 13        1           5.175  Lower spender

# %%
# 07. frequncy of customer

# %%
df_clean['days_since_prior_order'].describe()
# Out:
# count    6.064514e+06
# mean     1.110361e+01
# std      8.778698e+00
# min      0.000000e+00
# 25%      5.000000e+00
# 50%      8.000000e+00
# 75%      1.500000e+01
# max      3.000000e+01
# Name: days_since_prior_order, dtype: float64

# %%
df_clean.loc[df_clean['days_since_prior_order'] > 20, 'order_frequency'] = 'Non-frequent customer'

# %%
df_clean.loc[(df_clean['days_since_prior_order'] > 10) & (df_clean['days_since_prior_order'] <= 20), 'order_frequncy'] = 'Regular customer'

# %%
df_clean.loc[df_clean['days_since_prior_order'] <= 10, 'order_frequency'] = 'Frequent customer'

# %%
df_clean[['user_id', 'days_since_prior_order', 'order_frequency']].head()
# Out:
#     user_id  days_since_prior_order        order_frequency
# 0         1                     NaN                    NaN
# 2         1                     NaN                    NaN
# 6         1                    15.0                    NaN
# 12        1                    21.0  Non-frequent customer
# 13        1                    21.0  Non-frequent customer

# %%
df_clean.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', '4.8_clean_aggregated_data.pkl'))
